# %% [markdown]
# <a href="https://colab.research.google.com/github/siddhidamkondwar/Practical_Machine_Learning/blob/main/ML_6_6_26_DAY5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ONE HOT ENCODING :
#
# USED FOR NOMINAL SCALE VARIABLES (NO LOGICAL ORDER)
#
# NOT USEFULWHEN NUMBER OF CATEGORIES ARE TOO LARGE
#
# REGRESSION ,ANN,KNN,SVM
#
# # ORDINAL ENCODING
#
# VARIABLES WITH INHERENT RANKING OR RATING
#
# PRESERVE LOGICAL ORDER
#
# # FREQUENCY ENCODING (COUNTS)
#
# # BINARY ENCODING
#
# USED WHEN NO OF CATAGOERS ARE TOO LARGE

# %%
import pandas as pd

# %%
df = pd.DataFrame({
    'Education':[
        'Graduate',
        'PG',
        'High School',
        'Graduate',
        'PG'
    ]
})

education_map = {
    'High School':1,
    'Graduate':2,
    'PG':3
}

df['Education_Encoded'] = (
    df['Education']
    .map(education_map)
)

print(df)
# Out:
#      Education  Education_Encoded
# 0     Graduate                  2
# 1           PG                  3
# 2  High School                  1
# 3     Graduate                  2
# 4           PG                  3

# %%
# Frequency encoding
df = pd.DataFrame({
    'City':[
        'Mumbai',
        'Mumbai',
        'Mumbai',
        'Delhi',
        'Delhi',
        'Pune'
    ]
})

freq = df.City.value_counts()

df['City_Frequency'] = (df.City.map(freq))

# %%
df
# Out:
#      City  City_Frequency
# 0  Mumbai               3
# 1  Mumbai               3
# 2  Mumbai               3
# 3   Delhi               2
# 4   Delhi               2
# 5    Pune               1

# %% [markdown]
# # BINARY ENCODERS

# %%
pip install category_encoders
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.9/85.9 kB 2.5 MB/s eta 0:00:00
# ...

# %%
df = pd.DataFrame({
    'City': [
        'Mumbai',
        'Pune',
        'Delhi',
        'Chennai',
        'Kolkata'
    ]
})


#pip install category_encoders

from category_encoders import BinaryEncoder
encoder = BinaryEncoder(cols=['City'])
df_encoded = encoder.fit_transform(df)
print(df_encoded)
# Out:
#    City_0  City_1  City_2
# 0       0       0       1
# 1       0       1       0
# 2       0       1       1
# 3       1       0       0
# 4       1       0       1

# %%
df_encoded = encoder.transform(df)
result = pd.concat([df, df_encoded], axis=1)
print(result)
# Out:
#       City  City_0  City_1  City_2
# 0   Mumbai       0       0       1
# 1     Pune       0       1       0
# 2    Delhi       0       1       1
# 3  Chennai       1       0       0
# 4  Kolkata       1       0       1

# %%
df
# Out:
#       City
# 0   Mumbai
# 1     Pune
# 2    Delhi
# 3  Chennai
# 4  Kolkata
